# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as gs
import plotly.express as px

import warnings
warnings.filterwarnings("ignore")

# %%
row_data = pd.read_csv("superstore_row_data.csv")
df= row_data.copy()

# %%
df.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.shape
# Out:
# (9800, 18)

# %%
df.size
# Out:
# 176400

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
df.describe().T
# Out:
#               count          mean           std       min        25%  \
# Row ID       9800.0   4900.500000   2829.160653     1.000   2450.750
# Postal Code  9789.0  55273.322403  32041.223413  1040.000  23223.000
# Sales        9800.0    230.769059    626.651875     0.444     17.248
#
#                   50%        75%       max
# Row ID        4900.50   7350.250   9800.00
# Postal Code  58103.00  90008.000  99301.00
# Sales           54.49    210.605  22638.48

# %%
df.describe(include="all").T
# Out:
#                 count unique              top  freq          mean  \
# Row ID         9800.0    NaN              NaN   NaN        4900.5
# Order ID         9800   4922   CA-2018-100111    14           NaN
# Order Date       9800   1230       05/09/2017    38           NaN
# Ship Date        9800   1326       26/09/2018    34           NaN
# Ship Mode        9800      4   Standard Class  5859           NaN
# Customer ID      9800    793         WB-21850    35           NaN
# Customer Name    9800    793    William Brown    35           NaN
# Segment          9800      3         Consumer  5101           NaN
# Country          9800      1    United States  9800           NaN
# City             9800    529    New York City   891           NaN
# State            9800     49       California  1946           NaN
# Postal Code    9789.0    NaN              NaN   NaN  55273.322403
# Region           9800      4             West  3140           NaN
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
df.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df[df['Postal Code'].isna()]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2234    2235  CA-2018-104066  05/12/2018  10/12/2018  Standard Class
# 5274    5275  CA-2016-162887  07/11/2016  09/11/2016    Second Class
# 8798    8799  US-2017-150140  06/04/2017  10/04/2017  Standard Class
# 9146    9147  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9147    9148  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9148    9149  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9386    9387  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9387    9388  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9388    9389  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9389    9390  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9741    9742  CA-2016-117086  08/11/2016  12/11/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country        City  \
# ...

# %%
df.groupby(["City","State"])["Postal Code"].value_counts()
# Out:
# City         State         Postal Code
# Aberdeen     South Dakota  57401.0         1
# Abilene      Texas         79605.0         1
# Akron        Ohio          44312.0        20
# Albuquerque  New Mexico    87105.0        14
# Alexandria   Virginia      22304.0        16
#                                           ..
# Woonsocket   Rhode Island  2895.0          4
# Yonkers      New York      10701.0        15
# York         Pennsylvania  17403.0         5
# Yucaipa      California    92399.0         1
# Yuma         Arizona       85364.0         4
# Name: count, Length: 627, dtype: int64

# %%
df[df["State"]=="Vermont"]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2234    2235  CA-2018-104066  05/12/2018  10/12/2018  Standard Class
# 5274    5275  CA-2016-162887  07/11/2016  09/11/2016    Second Class
# 8798    8799  US-2017-150140  06/04/2017  10/04/2017  Standard Class
# 9146    9147  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9147    9148  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9148    9149  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9386    9387  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9387    9388  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9388    9389  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9389    9390  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9741    9742  CA-2016-117086  08/11/2016  12/11/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country        City  \
# ...

# %%
df[["State","Postal Code"]].head(60)
# Out:
#              State  Postal Code
# 0         Kentucky      42420.0
# 1         Kentucky      42420.0
# 2       California      90036.0
# 3          Florida      33311.0
# 4          Florida      33311.0
# 5       California      90032.0
# 6       California      90032.0
# 7       California      90032.0
# 8       California      90032.0
# 9       California      90032.0
# 10      California      90032.0
# 11      California      90032.0
# 12  North Carolina      28027.0
# 13      Washington      98103.0
# 14           Texas      76106.0
# 15           Texas      76106.0
# 16       Wisconsin      53711.0
# 17            Utah      84084.0
# 18      California      94109.0
# 19      California      94109.0
# 20      California      94109.0
# 21        Nebraska      68025.0
# 22        Nebraska      68025.0
# 23    Pennsylvania      19140.0
# 24            Utah      84057.0
# 25      California      90049.0
# 26      California      90049.0
# 27    Pennsylvania      19140.0
# ...

# %%
df[df["State"] == "Vermont"][["City", "Postal Code"]]
# Out:
#             City  Postal Code
# 2234  Burlington          NaN
# 5274  Burlington          NaN
# 8798  Burlington          NaN
# 9146  Burlington          NaN
# 9147  Burlington          NaN
# 9148  Burlington          NaN
# 9386  Burlington          NaN
# 9387  Burlington          NaN
# 9388  Burlington          NaN
# 9389  Burlington          NaN
# 9741  Burlington          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(" ","_").str.replace("-","_")

# %%
df.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub_category',
#        'product_name', 'sales'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    row_id        order_id  order_date   ship_date       ship_mode customer_id  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      customer_name    segment        country             city       state  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
cat_col = [feature for feature in df.columns if df[feature].dtype=="O"]
num_col = [feature for feature in df.columns if df[feature].dtype!="O"]

# %%
cat_col
# Out:
# ['order_id',
#  'order_date',
#  'ship_date',
#  'ship_mode',
#  'customer_id',
#  'customer_name',
#  'segment',
#  'country',
#  'city',
#  'state',
#  'region',
#  'product_id',
#  'category',
#  'sub_category',
#  'product_name']

# %%
num_col
# Out:
# ['row_id', 'postal_code', 'sales']

# %%
df.isnull().sum() / len(df)*100
# Out:
# row_id           0.000000
# order_id         0.000000
# order_date       0.000000
# ship_date        0.000000
# ship_mode        0.000000
# customer_id      0.000000
# customer_name    0.000000
# segment          0.000000
# country          0.000000
# city             0.000000
# state            0.000000
# postal_code      0.112245
# region           0.000000
# product_id       0.000000
# category         0.000000
# sub_category     0.000000
# product_name     0.000000
# sales            0.000000
# dtype: float64

# %%
df["postal_code"].isnull().sum() / len(df)*100
# Out:
# np.float64(0.11224489795918367)

# %%
df[["city","state","postal_code"]].value_counts(ascending=True)
# Out:
# city               state         postal_code
# Aberdeen           South Dakota  57401.0          1
# Abilene            Texas         79605.0          1
# Arlington Heights  Illinois      60004.0          1
# Yucaipa            California    92399.0          1
# Baytown            Texas         77520.0          1
#                                                ...
# New York City      New York      10011.0        193
# San Francisco      California    94122.0        195
# New York City      New York      10009.0        220
#                                  10024.0        225
#                                  10035.0        253
# Name: count, Length: 627, dtype: int64

# %% [markdown]
# # fill null value in postal_code

# %%
df["postal_code"].fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# row_id           0
# order_id         0
# order_date       0
# ship_date        0
# ship_mode        0
# customer_id      0
# customer_name    0
# segment          0
# country          0
# city             0
# state            0
# postal_code      0
# region           0
# product_id       0
# category         0
# sub_category     0
# product_name     0
# sales            0
# dtype: int64

# %%
df[df["postal_code"] == 0]
# Out:
#       row_id        order_id  order_date   ship_date       ship_mode  \
# 2234    2235  CA-2018-104066  05/12/2018  10/12/2018  Standard Class
# 5274    5275  CA-2016-162887  07/11/2016  09/11/2016    Second Class
# 8798    8799  US-2017-150140  06/04/2017  10/04/2017  Standard Class
# 9146    9147  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9147    9148  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9148    9149  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9386    9387  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9387    9388  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9388    9389  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9389    9390  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9741    9742  CA-2016-117086  08/11/2016  12/11/2016  Standard Class
#
#      customer_id     customer_name      segment        country        city  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   row_id         9800 non-null   int64
#  1   order_id       9800 non-null   object
#  2   order_date     9800 non-null   object
#  3   ship_date      9800 non-null   object
#  4   ship_mode      9800 non-null   object
#  5   customer_id    9800 non-null   object
#  6   customer_name  9800 non-null   object
#  7   segment        9800 non-null   object
#  8   country        9800 non-null   object
#  9   city           9800 non-null   object
#  10  state          9800 non-null   object
#  11  postal_code    9800 non-null   float64
#  12  region         9800 non-null   object
#  13  product_id     9800 non-null   object
#  14  category       9800 non-null   object
#  15  sub_category   9800 non-null   object
#  16  product_name   9800 non-null   object
# ...

# %%
num_col
# Out:
# ['row_id', 'postal_code', 'sales']

# %%
cat_col
# Out:
# ['order_id',
#  'order_date',
#  'ship_date',
#  'ship_mode',
#  'customer_id',
#  'customer_name',
#  'segment',
#  'country',
#  'city',
#  'state',
#  'region',
#  'product_id',
#  'category',
#  'sub_category',
#  'product_name']

# %%
df["order_date"] = pd.to_datetime(df["order_date"],dayfirst=True)
df["ship_date"] = pd.to_datetime(df["ship_date"],dayfirst=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   row_id         9800 non-null   int64
#  1   order_id       9800 non-null   object
#  2   order_date     9800 non-null   datetime64[ns]
#  3   ship_date      9800 non-null   datetime64[ns]
#  4   ship_mode      9800 non-null   object
#  5   customer_id    9800 non-null   object
#  6   customer_name  9800 non-null   object
#  7   segment        9800 non-null   object
#  8   country        9800 non-null   object
#  9   city           9800 non-null   object
#  10  state          9800 non-null   object
#  11  postal_code    9800 non-null   float64
#  12  region         9800 non-null   object
#  13  product_id     9800 non-null   object
#  14  category       9800 non-null   object
#  15  sub_category   9800 non-null   object
#  16  product_name   9800 non-null   object
# ...

# %% [markdown]
# # feature engineering

# %%
df["shipping_days"] = (df["ship_date"] - df["order_date"]).dt.days

# %%
df[["order_date","ship_date","shipping_days"]].head(10)
# Out:
#   order_date  ship_date  shipping_days
# 0 2017-11-08 2017-11-11              3
# 1 2017-11-08 2017-11-11              3
# 2 2017-06-12 2017-06-16              4
# 3 2016-10-11 2016-10-18              7
# 4 2016-10-11 2016-10-18              7
# 5 2015-06-09 2015-06-14              5
# 6 2015-06-09 2015-06-14              5
# 7 2015-06-09 2015-06-14              5
# 8 2015-06-09 2015-06-14              5
# 9 2015-06-09 2015-06-14              5

# %%
df.head()
# Out:
#    row_id        order_id order_date  ship_date       ship_mode customer_id  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      customer_name    segment        country             city       state  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.isnull().sum()
# Out:
# row_id           0
# order_id         0
# order_date       0
# ship_date        0
# ship_mode        0
# customer_id      0
# customer_name    0
# segment          0
# country          0
# city             0
# state            0
# postal_code      0
# region           0
# product_id       0
# category         0
# sub_category     0
# product_name     0
# sales            0
# shipping_days    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe().T
# Out:
#                 count                           mean                  min  \
# row_id         9800.0                         4900.5                  1.0
# order_date       9800  2017-05-01 05:13:51.673469440  2015-01-03 00:00:00
# ship_date        9800  2017-05-05 04:17:52.653061120  2015-01-07 00:00:00
# postal_code    9800.0                   55211.280918                  0.0
# sales          9800.0                     230.769059                0.444
# shipping_days  9800.0                       3.961122                  0.0
#
#                                25%                  50%                  75%  \
# row_id                     2450.75               4900.5              7350.25
# order_date     2016-05-24 00:00:00  2017-06-26 00:00:00  2018-05-15 00:00:00
# ship_date      2016-05-27 18:00:00  2017-06-29 00:00:00  2018-05-19 00:00:00
# postal_code                23223.0              57551.0              90008.0
# ...

# %% [markdown]
# # visualization

# %%
df.head()
# Out:
#    row_id        order_id order_date  ship_date       ship_mode customer_id  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      customer_name    segment        country             city       state  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
cat_col = [feature for feature in df.columns if df[feature].dtype=="O"]
num_col = [feature for feature in df.columns if df[feature].dtype!="O"]

# %%
cat_col
# Out:
# ['order_id',
#  'ship_mode',
#  'customer_id',
#  'customer_name',
#  'segment',
#  'country',
#  'city',
#  'state',
#  'region',
#  'product_id',
#  'category',
#  'sub_category',
#  'product_name']

# %%
df1=df['order_id'].value_counts(ascending=False)[:10]
sns.barplot(x=df1.index , y=df1.values,palette="rocket")
plt.xticks(rotation=45)
plt.xlabel("order_id")
plt.ylabel("count")
plt.title("top 10 order id")
plt.show()

# %%
df["ship_mode"].value_counts(ascending=False)
# Out:
# ship_mode
# Standard Class    5859
# Second Class      1902
# First Class       1501
# Same Day           538
# Name: count, dtype: int64

# %% [markdown]
# # sabse jyada konse ship mode se order hua h

# %%
sns.countplot(df["ship_mode"],palette="muted")
plt.xlabel("ship_mode")
plt.ylabel("count")
plt.title("ship_mode")
plt.show()

# %% [markdown]
# # stander class me sabse jyada order hue hai

# %%
df["customer_id"].value_counts(ascending=False).head(10)
# Out:
# customer_id
# WB-21850    35
# MA-17560    34
# PP-18955    34
# JL-15835    33
# JD-15895    32
# CK-12205    32
# SV-20365    32
# AP-10915    31
# EP-13915    31
# ZC-21910    31
# Name: count, dtype: int64

# %% [markdown]
# # konsi customer id se sabse jyada order hua hai

# %%
df2 = df["customer_id"].value_counts(ascending=False).head(5)
sns.barplot(x=df2.index , y=df2.values , palette="viridis")
plt.xticks(rotation= 45)
plt.xlabel("customer_id")
plt.ylabel("count")
plt.title("count order by customer id")
plt.show()

# %% [markdown]
# # WB-21850 customer id se sabse jyada order hue hai

# %%
cat_col
# Out:
# ['order_id',
#  'ship_mode',
#  'customer_id',
#  'customer_name',
#  'segment',
#  'country',
#  'city',
#  'state',
#  'region',
#  'product_id',
#  'category',
#  'sub_category',
#  'product_name']

# %%
df["customer_name"].value_counts(ascending=False)[:10]
# Out:
# customer_name
# William Brown          35
# Matt Abelman           34
# Paul Prost             34
# John Lee               33
# Jonathan Doherty       32
# Chloris Kastensmidt    32
# Seth Vernon            32
# Arthur Prichep         31
# Emily Phan             31
# Zuschuss Carroll       31
# Name: count, dtype: int64

# %% [markdown]
# # sabse jyada konse customer ne order kiya hai

# %%
df3 = df["customer_name"].value_counts(ascending=False)[:10]
sns.barplot(x=df3.values , y=df3.index,palette = "coolwarm")
plt.yticks(rotation=45)
plt.xlabel("customer_name")
plt.ylabel("count")
plt.title("count order by customer name")
plt.show()

# %% [markdown]
# # William Brown ne sabse jyada 35 order kiye hai

# %%
df["segment"].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %% [markdown]
# # konse segment se sabse jyada order hue hai

# %%
sns.countplot(df["segment"],palette = "rocket")
plt.xlabel("segment")
plt.ylabel("count")
plt.title("count order by segment")
plt.show()

# %% [markdown]
# # consumer segment se sabse jyada order hue hai 5101

# %%
cat_col
# Out:
# ['order_id',
#  'ship_mode',
#  'customer_id',
#  'customer_name',
#  'segment',
#  'country',
#  'city',
#  'state',
#  'region',
#  'product_id',
#  'category',
#  'sub_category',
#  'product_name']

# %% [markdown]
# # konsi city se sabse jyada order hue hai

# %%
df["city"].value_counts()
# Out:
# city
# New York City    891
# Los Angeles      728
# Philadelphia     532
# San Francisco    500
# Seattle          426
#                 ...
# Goldsboro          1
# Montebello         1
# Abilene            1
# Normal             1
# Springdale         1
# Name: count, Length: 529, dtype: int64

# %%
df5 = df["city"].value_counts(ascending=False).head(5)
sns.barplot(x=df5.index , y=df5.values , palette="rocket")
plt.xticks(rotation=45)
plt.xlabel("city")
plt.ylabel("count")
plt.title("count order by city")
plt.show()

# %% [markdown]
# # new york city se sabse jyada order hue hai

# %% [markdown]
# # qtn - konse state se sabse jyada order hue hai

# %%
df["state"].value_counts()
# Out:
# state
# California              1946
# New York                1097
# Texas                    973
# Pennsylvania             582
# Washington               504
# Illinois                 483
# Ohio                     454
# Florida                  373
# Michigan                 253
# North Carolina           247
# Virginia                 224
# Arizona                  223
# Tennessee                183
# Colorado                 179
# Georgia                  177
# Kentucky                 137
# Indiana                  135
# Massachusetts            135
# Oregon                   122
# New Jersey               122
# Maryland                 105
# Wisconsin                105
# Delaware                  93
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              55
# Utah                      53
# Mississippi               53
# ...

# %%
df6 = df["state"].value_counts(ascending=False)[:5]
sns.barplot(x=df6.index,y=df6.values,palette="rocket")
plt.xticks(rotation=45)
plt.xlabel("state")
plt.ylabel("count")
plt.title("count order by state")
plt.show()

# %% [markdown]
# # california se 1946 sabse jyada order hue hai

# %%
cat_col
# Out:
# ['order_id',
#  'ship_mode',
#  'customer_id',
#  'customer_name',
#  'segment',
#  'country',
#  'city',
#  'state',
#  'region',
#  'product_id',
#  'category',
#  'sub_category',
#  'product_name']

# %%
df["region"].value_counts()
# Out:
# region
# West       3140
# East       2785
# Central    2277
# South      1598
# Name: count, dtype: int64

# %%
sns.countplot(df["region"],palette="rocket")
plt.xlabel("region")
plt.ylabel("count")
plt.title("count order by region")
plt.show()

# %% [markdown]
# # west region se 3140 order hue hai sabse jyada

# %%
cat_col
# Out:
# ['order_id',
#  'ship_mode',
#  'customer_id',
#  'customer_name',
#  'segment',
#  'country',
#  'city',
#  'state',
#  'region',
#  'product_id',
#  'category',
#  'sub_category',
#  'product_name']

# %%
df["product_id"].unique()
# Out:
# array(['FUR-BO-10001798', 'FUR-CH-10000454', 'OFF-LA-10000240', ...,
#        'TEC-MA-10003589', 'OFF-AP-10003099', 'TEC-PH-10002645'],
#       dtype=object)

# %%
df["product_id"].value_counts()
# Out:
# product_id
# OFF-PA-10001970    19
# TEC-AC-10003832    18
# FUR-FU-10004270    16
# TEC-AC-10003628    15
# FUR-CH-10002647    15
#                    ..
# TEC-AC-10002380     1
# TEC-PH-10002817     1
# TEC-MA-10003589     1
# OFF-AP-10003099     1
# TEC-PH-10002645     1
# Name: count, Length: 1861, dtype: int64

# %% [markdown]
# # sabse jyada konsi product id se order hua hai

# %%
df7= df["product_id"].value_counts(ascending=False)[:10]
sns.barplot(x=df7.index,y=df7.values,palette="rocket")
plt.xticks(rotation=90)
plt.xlabel("product_id")
plt.ylabel("count")
plt.title("count order by product_id")
plt.show()

# %% [markdown]
# # OFF-PA-10001970 se sabse jyada order hua

# %%
cat_col
# Out:
# ['order_id',
#  'ship_mode',
#  'customer_id',
#  'customer_name',
#  'segment',
#  'country',
#  'city',
#  'state',
#  'region',
#  'product_id',
#  'category',
#  'sub_category',
#  'product_name']

# %% [markdown]
# # sabse jyada konsi category order hui hai

# %%
df["category"].value_counts()
# Out:
# category
# Office Supplies    5909
# Furniture          2078
# Technology         1813
# Name: count, dtype: int64

# %% [markdown]
# # Office Supplies se

# %%
sns.countplot(df["category"],palette="rocket")
plt.xlabel("category")
plt.ylabel("count")
plt.title("count order by category")
plt.show()

# %%
cat_col
# Out:
# ['order_id',
#  'ship_mode',
#  'customer_id',
#  'customer_name',
#  'segment',
#  'country',
#  'city',
#  'state',
#  'region',
#  'product_id',
#  'category',
#  'sub_category',
#  'product_name']

# %%
df["sub_category"].value_counts()
# Out:
# sub_category
# Binders        1492
# Paper          1338
# Furnishings     931
# Phones          876
# Storage         832
# Art             785
# Accessories     756
# Chairs          607
# Appliances      459
# Labels          357
# Tables          314
# Envelopes       248
# Bookcases       226
# Fasteners       214
# Supplies        184
# Machines        115
# Copiers          66
# Name: count, dtype: int64

# %% [markdown]
# # sabse jyada konsi sub_category se order hua hai

# %%
df8 = df["sub_category"].value_counts(ascending=False).head(5)
sns.barplot(x=df8.index , y=df8.values , palette="muted")
plt.xticks(rotation=90)
plt.xlabel("sub_category")
plt.ylabel("sub_category count")
plt.title("maximum order by sub_catgory")
plt.show()

# %% [markdown]
# # binders 1492 order hue hai

# %%
cat_col
# Out:
# ['order_id',
#  'ship_mode',
#  'customer_id',
#  'customer_name',
#  'segment',
#  'country',
#  'city',
#  'state',
#  'region',
#  'product_id',
#  'category',
#  'sub_category',
#  'product_name']

# %% [markdown]
# # konse product name ka sabse jyada order hua hai

# %%
df8 = df["product_name"].value_counts(ascending=False).head(5)
sns.barplot(x=df8.index , y=df8.values , palette="muted")
plt.xticks(rotation=90)
plt.xlabel("product_name")
plt.ylabel("product_name count")
plt.title("maximum order by product_name")
plt.show()

# %% [markdown]
# # staple envelope ka 47 order hua hai

# %%
df["product_name"].value_counts(ascending=False).head(5)
# Out:
# product_name
# Staple envelope            47
# Staples                    46
# Easy-staple paper          44
# Avery Non-Stick Binders    20
# Staples in misc. colors    18
# Name: count, dtype: int64

# %%
cat_col
# Out:
# ['order_id',
#  'ship_mode',
#  'customer_id',
#  'customer_name',
#  'segment',
#  'country',
#  'city',
#  'state',
#  'region',
#  'product_id',
#  'category',
#  'sub_category',
#  'product_name']

# %%
num_col
# Out:
# ['row_id', 'order_date', 'ship_date', 'postal_code', 'sales', 'shipping_days']

# %%
df
# Out:
#       row_id        order_id order_date  ship_date       ship_mode  \
# 0          1  CA-2017-152156 2017-11-08 2017-11-11    Second Class
# 1          2  CA-2017-152156 2017-11-08 2017-11-11    Second Class
# 2          3  CA-2017-138688 2017-06-12 2017-06-16    Second Class
# 3          4  US-2016-108966 2016-10-11 2016-10-18  Standard Class
# 4          5  US-2016-108966 2016-10-11 2016-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9795    9796  CA-2017-125920 2017-05-21 2017-05-28  Standard Class
# 9796    9797  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
# 9797    9798  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
# 9798    9799  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
# 9799    9800  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
#
#      customer_id     customer_name    segment        country             city  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df.drop(columns="row_id",axis=1,inplace=True)

# %%
df
# Out:
#             order_id order_date  ship_date       ship_mode customer_id  \
# 0     CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1     CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2     CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3     US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4     US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9795  CA-2017-125920 2017-05-21 2017-05-28  Standard Class    SH-19975
# 9796  CA-2016-128608 2016-01-12 2016-01-17  Standard Class    CS-12490
# 9797  CA-2016-128608 2016-01-12 2016-01-17  Standard Class    CS-12490
# 9798  CA-2016-128608 2016-01-12 2016-01-17  Standard Class    CS-12490
# 9799  CA-2016-128608 2016-01-12 2016-01-17  Standard Class    CS-12490
#
#          customer_name    segment        country             city       state  \
# ...

# %%
cat_col
# Out:
# ['order_id',
#  'ship_mode',
#  'customer_id',
#  'customer_name',
#  'segment',
#  'country',
#  'city',
#  'state',
#  'region',
#  'product_id',
#  'category',
#  'sub_category',
#  'product_name']

# %%
df
# Out:
#             order_id order_date  ship_date       ship_mode customer_id  \
# 0     CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1     CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2     CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3     US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4     US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9795  CA-2017-125920 2017-05-21 2017-05-28  Standard Class    SH-19975
# 9796  CA-2016-128608 2016-01-12 2016-01-17  Standard Class    CS-12490
# 9797  CA-2016-128608 2016-01-12 2016-01-17  Standard Class    CS-12490
# 9798  CA-2016-128608 2016-01-12 2016-01-17  Standard Class    CS-12490
# 9799  CA-2016-128608 2016-01-12 2016-01-17  Standard Class    CS-12490
#
#          customer_name    segment        country             city       state  \
# ...

# %%
nm_col= [feature for feature in df.columns if df[feature].dtype !="O"]

# %%
nm_col
# Out:
# ['order_date', 'ship_date', 'postal_code', 'sales', 'shipping_days']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       9800 non-null   object
#  1   order_date     9800 non-null   datetime64[ns]
#  2   ship_date      9800 non-null   datetime64[ns]
#  3   ship_mode      9800 non-null   object
#  4   customer_id    9800 non-null   object
#  5   customer_name  9800 non-null   object
#  6   segment        9800 non-null   object
#  7   country        9800 non-null   object
#  8   city           9800 non-null   object
#  9   state          9800 non-null   object
#  10  postal_code    9800 non-null   float64
#  11  region         9800 non-null   object
#  12  product_id     9800 non-null   object
#  13  category       9800 non-null   object
#  14  sub_category   9800 non-null   object
#  15  product_name   9800 non-null   object
#  16  sales          9800 non-null   float64
# ...

# %%
df["order_date"] = pd.to_datetime(df["order_date"])
df["order_day"] = df["order_date"].dt.day
df["order_month"] = df["order_date"].dt.month
df["order_year"] = df["order_date"].dt.year

# %%
df["ship_date"] = pd.to_datetime(df["ship_date"])
df["ship_day"] = df["order_date"].dt.day
df["ship_month"] = df["order_date"].dt.month
df["ship_year"] = df["order_date"].dt.year

# %%
df.drop(columns=["order_date","ship_date"],axis=1,inplace=True)

# %%
df
# Out:
#             order_id       ship_mode customer_id     customer_name    segment  \
# 0     CA-2017-152156    Second Class    CG-12520       Claire Gute   Consumer
# 1     CA-2017-152156    Second Class    CG-12520       Claire Gute   Consumer
# 2     CA-2017-138688    Second Class    DV-13045   Darrin Van Huff  Corporate
# 3     US-2016-108966  Standard Class    SO-20335    Sean O'Donnell   Consumer
# 4     US-2016-108966  Standard Class    SO-20335    Sean O'Donnell   Consumer
# ...              ...             ...         ...               ...        ...
# 9795  CA-2017-125920  Standard Class    SH-19975     Sally Hughsby  Corporate
# 9796  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9797  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9798  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9799  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
#
# ...

# %%
no_col = df.dtypes[df.dtypes !="object"]

# %%
no_col
# Out:
# postal_code      float64
# sales            float64
# shipping_days      int64
# order_day          int32
# order_month        int32
# order_year         int32
# ship_day           int32
# ship_month         int32
# ship_year          int32
# dtype: object

# %% [markdown]
# # sabse jyada konse postal code per order hua hai

# %%
df9=df["postal_code"].value_counts(ascending=False).head(5)
ax = sns.barplot(x=df9.index, y=df9.values, palette="rocket")
for container in ax.containers:
    ax.bar_label(container)
plt.xticks(rotation=45)
plt.xlabel("postal_code")
plt.ylabel("count postal code")
plt.title("postal code wise order")
plt.show()

# %%
df["postal_code"].value_counts(ascending=False).head(5)
# Out:
# postal_code
# 10035.0    253
# 10024.0    225
# 10009.0    220
# 94122.0    195
# 10011.0    193
# Name: count, dtype: int64

# %% [markdown]
# # 10035.0 wale me sabse jyada order kiye gye hai

# %%
df10 = df["sales"].value_counts(ascending=False).head(5)
sns.barplot(x=df10.index , y=df10.values , palette="rocket")
plt.xticks(rotation=45)
plt.xlabel("sales")
plt.ylabel("count")
plt.title("count order by sales")
plt.show()

# %%
df["sales"].value_counts(ascending=False).head(5)
# Out:
# sales
# 12.960    55
# 19.440    39
# 15.552    39
# 10.368    35
# 25.920    34
# Name: count, dtype: int64

# %%
df.head(5)
# Out:
#          order_id       ship_mode customer_id    customer_name    segment  \
# 0  CA-2017-152156    Second Class    CG-12520      Claire Gute   Consumer
# 1  CA-2017-152156    Second Class    CG-12520      Claire Gute   Consumer
# 2  CA-2017-138688    Second Class    DV-13045  Darrin Van Huff  Corporate
# 3  US-2016-108966  Standard Class    SO-20335   Sean O'Donnell   Consumer
# 4  US-2016-108966  Standard Class    SO-20335   Sean O'Donnell   Consumer
#
#          country             city       state  postal_code region  ...  \
# 0  United States        Henderson    Kentucky      42420.0  South  ...
# 1  United States        Henderson    Kentucky      42420.0  South  ...
# 2  United States      Los Angeles  California      90036.0   West  ...
# 3  United States  Fort Lauderdale     Florida      33311.0  South  ...
# 4  United States  Fort Lauderdale     Florida      33311.0  South  ...
#
#   sub_category                                       product_name     sales  \
# ...

# %%
# average sales
df.sales.mean()
# Out:
# np.float64(230.7690594591837)

# %% [markdown]
# # ship mode me sabse jyada average sales kiski hai

# %%
df.groupby(["ship_mode"])["sales"].mean()
# Out:
# ship_mode
# First Class       230.228020
# Same Day          232.749143
# Second Class      236.547939
# Standard Class    228.849856
# Name: sales, dtype: float64

# %% [markdown]
# # Second Class	236.547939

# %%
# toal sales
df.sales.sum()
# Out:
# np.float64(2261536.7827000003)

# %%
# min sales
df.sales.min()
# Out:
# 0.444

# %%
# max sales
df.sales.max()
# Out:
# 22638.48

# %% [markdown]
# # Kaunsi Category sabse zyada sales generate karti hai

# %%
df.groupby(["category"])["sales"].sum()
# Out:
# category
# Furniture          728658.5757
# Office Supplies    705422.3340
# Technology         827455.8730
# Name: sales, dtype: float64

# %%
a1 = df.groupby(["category"])["sales"].sum()
ax =sns.barplot(x=a1.index , y=a1.values , palette="rocket")
for container in ax.containers:
    ax.bar_label(container)
plt.xticks(rotation=45)
plt.xlabel("category")
plt.ylabel("sales")
plt.title("sales by category")
plt.show()

# %% [markdown]
# # Technology	827455.8730

# %% [markdown]
# # Kaunsi Category sabse kam sales generate karti hai

# %%
a2 = df.groupby(["category"])["sales"].sum().sort_values(ascending=True)
sns.barplot(x=a2.index , y=a2.values , palette="viridis")
plt.xlabel("category")
plt.ylabel("sales count")
plt.title("sales by category")
plt.show()

# %% [markdown]
# # Office Supplies	705422.3340

# %% [markdown]
# # top sub category konsi hai

# %%
df.sub_category.value_counts().head(1)
# Out:
# sub_category
# Binders    1492
# Name: count, dtype: int64

# %% [markdown]
# # Binders	1492

# %%
sns.countplot(df["sub_category"],palette="coolwarm")
plt.xlabel("sub_category")
plt.ylabel("count")
plt.title("count order by sub_category")
plt.show()

# %%
a3 = df.groupby(["sub_category"])["sales"].sum().sort_values(ascending=False).head(5)
ax = sns.barplot(x=a3.index , y=a3.values , palette="muted")
for container in ax.containers:
    ax.bar_label(container)
plt.xticks(rotation=45)
plt.xlabel("sub_category")
plt.ylabel("sales count")
plt.title("sales by sub_category")
plt.show()
#

# %% [markdown]
# # total sales ke hisab se phone hai

# %%
a3 = df.groupby(["sub_category"])["sales"].sum().sort_values(ascending=True).head(5)
ax = sns.barplot(x=a3.index , y=a3.values , palette="muted")
for container in ax.containers:
    ax.bar_label(container)
plt.xticks(rotation=45)
plt.xlabel("sub_category")
plt.ylabel("sales count")
plt.title("sales by sub_category")
plt.show()

# %% [markdown]
# # sabse kam sub category ki jo total sales hai wo fasteners ki hai 3001.96

# %%
# total unique customer
df.customer_name.nunique()
# Out:
# 793

# %%
# total unique order
df.order_id.nunique()
# Out:
# 4922

# %%
# top 10 customer konse jinhone sabse jyada sales ki hai

df.groupby(["customer_name"])["sales"].sum().sort_values(ascending=False).head(10)
# Out:
# customer_name
# Sean Miller           25043.050
# Tamara Chand          19052.218
# Raymond Buch          15117.339
# Tom Ashbrook          14595.620
# Adrian Barton         14473.571
# Ken Lonsdale          14175.229
# Sanjit Chand          14142.334
# Hunter Lopez          12873.298
# Sanjit Engle          12209.438
# Christopher Conant    12129.072
# Name: sales, dtype: float64

# %%
a3 = df.groupby(["customer_name"])["sales"].sum().sort_values(ascending=False).head(10)
az =sns.barplot(x=a3.values , y=a3.index , palette="viridis")
for container in az.containers:
    az.bar_label(container)
plt.xlabel("customer_name")
plt.ylabel("sales count")
plt.title("sales by customer_name")
plt.show()

# %% [markdown]
# # Sean Miller	25043.050

# %%
# top customer by no of order

df.groupby(["customer_name"])["order_id"].nunique().sort_values(ascending=False).head(1)
# Out:
# customer_name
# Emily Phan    17
# Name: order_id, dtype: int64

# %% [markdown]
# # Emily Phan	17 order ke saath hamara top customer hai

# %%
df
# Out:
#             order_id       ship_mode customer_id     customer_name    segment  \
# 0     CA-2017-152156    Second Class    CG-12520       Claire Gute   Consumer
# 1     CA-2017-152156    Second Class    CG-12520       Claire Gute   Consumer
# 2     CA-2017-138688    Second Class    DV-13045   Darrin Van Huff  Corporate
# 3     US-2016-108966  Standard Class    SO-20335    Sean O'Donnell   Consumer
# 4     US-2016-108966  Standard Class    SO-20335    Sean O'Donnell   Consumer
# ...              ...             ...         ...               ...        ...
# 9795  CA-2017-125920  Standard Class    SH-19975     Sally Hughsby  Corporate
# 9796  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9797  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9798  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9799  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
#
# ...

# %%
# average sales per customer
df.groupby("customer_id")["sales"].sum().mean()
# Out:
# np.float64(2851.874883606558)

# %%
# repeat customer kitne hai
order = df.groupby(["customer_id"])["order_id"].nunique()
repeat_customer = (order>1).sum()
print(repeat_customer)
# Out:
# 780

# %% [markdown]
# ## Kaunsa Segment sabse zyada sales generate karta h

# %%
df.groupby("segment")["sales"].sum().sort_values(ascending=False)
# Out:
# segment
# Consumer       1.148061e+06
# Corporate      6.884941e+05
# Home Office    4.249822e+05
# Name: sales, dtype: float64

# %%
a4 = df.groupby("segment")["sales"].sum().sort_values(ascending=False)
ax = sns.barplot(x=a4.index , y=a4.values , palette="rocket")
for container in ax.containers:
    ax.bar_label(container)
plt.xticks(rotation=45)
plt.xlabel("segment")
plt.ylabel("sales count")
plt.title("sales by segment")
plt.show()

# %% [markdown]
# # consumer wala segment sabse jyada sales genrate karta hai

# %%
prctge = df.groupby("segment")["sales"].sum()
prctge/df["sales"].sum() *100
# Out:
# segment
# Consumer       50.764619
# Corporate      30.443638
# Home Office    18.791743
# Name: sales, dtype: float64

# %% [markdown]
# # konsa region sabse jyada sales deta hai

# %%
df.groupby("region")["sales"].sum().sort_values(ascending=False)
# Out:
# region
# West       710219.6845
# East       669518.7260
# Central    492646.9132
# South      389151.4590
# Name: sales, dtype: float64

# %%
a5 = df.groupby("region")["sales"].sum().sort_values(ascending=False)
ax = sns.barplot(x=a5.index , y=a5.values , palette="rocket")
for container in ax.containers:
    ax.bar_label(container)
plt.xlabel("region")
plt.ylabel("sales count")
plt.title("sales by region")
plt.show()

# %% [markdown]
# # West region sabse jyada sales deta hai =	710219.6845  or sabse kam South	region me hui hai = 389151.4590

# %% [markdown]
# # top 10 state by sales

# %%
a6 = df.groupby("state")["sales"].sum().sort_values(ascending=False)[:10]
sns.barplot(x=a6.index , y=a6.values , palette="rocket")
plt.xticks(rotation=45)
plt.xlabel("state")
plt.ylabel("sales count")
plt.title("sales by state")
plt.show()

# %% [markdown]
# # california me sabse jyada hai

# %%
a6 = df.groupby("state")["sales"].sum().sort_values(ascending=True)[:10]
sns.barplot(x=a6.index , y=a6.values , palette="rocket")
plt.xticks(rotation=45)
plt.xlabel("state")
plt.ylabel("sales count")
plt.title("sales by state")
plt.show()

# %% [markdown]
# # north dakota me sabse kam hai

# %%
# top 10 city by sales
a7 = df.groupby("city")["sales"].sum().sort_values(ascending=False)[:10]
sns.barplot(x=a7.index , y=a7.values , palette="rocket")
plt.xticks(rotation=45)
plt.xlabel("city")
plt.ylabel("sales count")
plt.title("sales by city")
plt.show()

# new york city me sabse jyada

# %%
a7 = df.groupby("city")["sales"].sum().sort_values(ascending=True)[:10]
sns.barplot(x=a7.index , y=a7.values , palette="rocket")
plt.xticks(rotation=45)
plt.xlabel("city")
plt.ylabel("sales count")
plt.title("sales by city")
plt.show()

# %% [markdown]
# # albilene city me sabse kam sales hui hai

# %%
# Top 5 Postal Codes by Orders
df.postal_code.value_counts().head(5)
# Out:
# postal_code
# 10035.0    253
# 10024.0    225
# 10009.0    220
# 94122.0    195
# 10011.0    193
# Name: count, dtype: int64

# %%
# konsa ship mode sabse jyada use hua hai
df.ship_mode.value_counts()

# Standard Class sabse jyada use hua hai
# Out:
# ship_mode
# Standard Class    5859
# Second Class      1902
# First Class       1501
# Same Day           538
# Name: count, dtype: int64

# %% [markdown]
# # konsa shiping mode sabse jyada sales deta hai

# %%
df.groupby("ship_mode")["sales"].sum()
# Out:
# ship_mode
# First Class       3.455723e+05
# Same Day          1.252190e+05
# Second Class      4.499142e+05
# Standard Class    1.340831e+06
# Name: sales, dtype: float64

# %%
b1 = df.groupby("ship_mode")["sales"].sum()
ax = sns.barplot(x=b1.index , y=b1.values , palette="rocket")
for container in ax.containers:
    ax.bar_label(container)
plt.xlabel("ship mode")
plt.ylabel("count ship mode")
plt.title("sales count by ship mode")
plt.show()

# Standard Class

# %%
df
# Out:
#             order_id       ship_mode customer_id     customer_name    segment  \
# 0     CA-2017-152156    Second Class    CG-12520       Claire Gute   Consumer
# 1     CA-2017-152156    Second Class    CG-12520       Claire Gute   Consumer
# 2     CA-2017-138688    Second Class    DV-13045   Darrin Van Huff  Corporate
# 3     US-2016-108966  Standard Class    SO-20335    Sean O'Donnell   Consumer
# 4     US-2016-108966  Standard Class    SO-20335    Sean O'Donnell   Consumer
# ...              ...             ...         ...               ...        ...
# 9795  CA-2017-125920  Standard Class    SH-19975     Sally Hughsby  Corporate
# 9796  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9797  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9798  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9799  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
#
# ...

# %%
df.rename(columns={"shipping_days":"shipping_duration"},inplace=True)

# %%
df.columns
# Out:
# Index(['order_id', 'ship_mode', 'customer_id', 'customer_name', 'segment',
#        'country', 'city', 'state', 'postal_code', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales',
#        'shipping_duration', 'order_day', 'order_month', 'order_year',
#        'ship_day', 'ship_month', 'ship_year'],
#       dtype='object')

# %%
# average shipping duration kya hai
df.shipping_duration.mean()

# approx - 4 days
# Out:
# np.float64(3.9611224489795918)

# %%
# fasted ship mode konsa hai
df.groupby("ship_mode")["shipping_duration"].mean().sort_values(ascending=False)


# same day wala fasted hai
# Out:
# ship_mode
# Standard Class    5.008363
# Second Class      3.249211
# First Class       2.179214
# Same Day          0.044610
# Name: shipping_duration, dtype: float64

# %% [markdown]
# # year wise sales

# %%
df
# Out:
#             order_id       ship_mode customer_id     customer_name    segment  \
# 0     CA-2017-152156    Second Class    CG-12520       Claire Gute   Consumer
# 1     CA-2017-152156    Second Class    CG-12520       Claire Gute   Consumer
# 2     CA-2017-138688    Second Class    DV-13045   Darrin Van Huff  Corporate
# 3     US-2016-108966  Standard Class    SO-20335    Sean O'Donnell   Consumer
# 4     US-2016-108966  Standard Class    SO-20335    Sean O'Donnell   Consumer
# ...              ...             ...         ...               ...        ...
# 9795  CA-2017-125920  Standard Class    SH-19975     Sally Hughsby  Corporate
# 9796  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9797  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9798  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
# 9799  CA-2016-128608  Standard Class    CS-12490  Cindy Schnelling  Corporate
#
# ...

# %%
df.groupby("order_year")["sales"].sum().sort_values(ascending=False)
# Out:
# order_year
# 2018    722052.0192
# 2017    600192.5500
# 2015    479856.2081
# 2016    459436.0054
# Name: sales, dtype: float64

# %% [markdown]
# # 2018 me sabse jyada sale hui hai or sabse kam 2016 me

# %%
s1 = df.groupby("order_year")["sales"].sum().sort_values(ascending=False)
sns.barplot(x=s1.index , y=s1.values , palette="viridis")
plt.xlabel("order_year")
plt.ylabel("sales count")
plt.title("sales by order_year")
plt.show()

# %% [markdown]
# # konse month me sabse jyada sale hui hai

# %%
s2 = df.groupby("order_month")["sales"].sum().sort_values(ascending=False)
sns.barplot(x=s2.index , y=s2.values , palette="viridis")
plt.xlabel("order_month")
plt.ylabel("sales count")
plt.title("sales by order_month")
plt.show()

# %% [markdown]
# # sabse jyada nov(11 month) me hui hai or sabse kam feb(2 month) me hui hai

# %% [markdown]
# # year over year sales growth btao

# %%
yr_sale = df.groupby("order_year")["sales"].sum()
yr_sale.pct_change() * 100
# Out:
# order_year
# 2015          NaN
# 2016    -4.255484
# 2017    30.636812
# 2018    20.303396
# Name: sales, dtype: float64

# %% [markdown]
# # 2017 or 18 me strong growth hai jabki 2016 me sales ki growth gir rhi hai

# %% [markdown]
# # Category + Region mein highest sales combination

# %%
df.groupby(["category","region"])["sales"].sum().sort_values(ascending=False).to_frame()
# Out:
#                                sales
# category        region
# Technology      East     263116.5270
#                 West     247404.9300
# Furniture       West     245348.2455
# Office Supplies West     217466.5090
# Furniture       East     206461.3880
# Office Supplies East     199940.8110
# Technology      Central  168739.2080
# Office Supplies Central  163590.2430
# Furniture       Central  160317.4622
# Technology      South    148195.2080
# Office Supplies South    124424.7710
# Furniture       South    116531.4800

# %%
df.groupby(["category","region"])["sales"].sum().sort_values(ascending=False).unstack()
# Out:
# region               Central        East       South         West
# category
# Furniture        160317.4622  206461.388  116531.480  245348.2455
# Office Supplies  163590.2430  199940.811  124424.771  217466.5090
# Technology       168739.2080  263116.527  148195.208  247404.9300

# %%
df.groupby(["category","region"])["sales"].sum().sort_values(ascending=False)

sns.barplot(data=df , x="category", y="sales", hue="region")
plt.xlabel("category")
plt.ylabel("sales count")
plt.title("sales by category")
plt.show()

# %%
# Segment + Category ka highest sales combination

sns.barplot(data=df , x="segment", y="sales", hue="category")
plt.xlabel("segment")
plt.ylabel("sales count")
plt.title("sales by segment")
plt.show()

# %%
# top 10 product

df.groupby("product_name")["sales"].sum().sort_values(ascending=False).head(10)
# Out:
# product_name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: sales, dtype: float64

# %%
# Category ka Sales contribution percentage
prct= df.groupby("category")["sales"].sum()
prct / df["sales"].sum() *100
# Out:
# category
# Furniture          32.219621
# Office Supplies    31.192167
# Technology         36.588212
# Name: sales, dtype: float64

# %%
# Top 20% customers total sales ka kitna generate karte hain
cat_sales = df.groupby("customer_id")["sales"].sum().sort_values(ascending=False)
top20 = int(len(cat_sales)*0.20)
cat_sales.head(top20).sum() / df["sales"].sum() * 100
# Out:
# np.float64(48.29268676302922)

# %%
# Sales distribution mein outliers hai ya nhi

sns.boxplot(df["sales"])
plt.xlabel("sales")
plt.show()

# %%
# Top 10 customers ka total sales contribution
top10 = df.groupby("customer_id")["sales"].sum().sort_values(ascending=False).head(10)
top10.sum()

# 153811.16 contribution hai
# Out:
# np.float64(153811.16900000002)

# %%
df.to_csv("superstore_sales_clean_data.csv", index=False)

# %%
from google.colab import files
files.download("superstore_sales_clean_data.csv")
